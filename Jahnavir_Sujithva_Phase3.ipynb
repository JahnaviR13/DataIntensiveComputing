# %% [markdown]
# # Phase 1

# %% [markdown]
# # DATA PROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
##PHASE -3
#pip install anvil-uplink
import anvil.server

anvil.server.connect("server_HVM6NNJM7SAXAA5AELG3T3Y5-2V4E6ZL256JOHYYD")
##PHASE -3
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default Environment" as SERVER

# %%
df = pd.read_csv("neo_v2[1].csv")

# %%
df.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
df.tail()
# Out:
#              id        name  est_diameter_min  est_diameter_max  \
# 90831   3763337  (2016 VX1)          0.026580          0.059435
# 90832   3837603  (2019 AD3)          0.016771          0.037501
# 90833  54017201  (2020 JP3)          0.031956          0.071456
# 90834  54115824  (2021 CN5)          0.007321          0.016370
# 90835  54205447  (2021 TW7)          0.039862          0.089133
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 90831       52078.886692   1.230039e+07         Earth          False
# 90832       46114.605073   5.432121e+07         Earth          False
# 90833        7566.807732   2.840077e+07         Earth          False
# 90834       69199.154484   6.869206e+07         Earth          False
# 90835       27024.455553   5.977213e+07         Earth          False
#
#        absolute_magnitude  hazardous
# 90831               25.00      False
# 90832               26.00      False
# 90833               24.60      False
# 90834               27.80      False
# 90835               24.12      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  90836 non-null  int64
#  1   name                90836 non-null  object
#  2   est_diameter_min    90836 non-null  float64
#  3   est_diameter_max    90836 non-null  float64
#  4   relative_velocity   90836 non-null  float64
#  5   miss_distance       90836 non-null  float64
#  6   orbiting_body       90836 non-null  object
#  7   sentry_object       90836 non-null  bool
#  8   absolute_magnitude  90836 non-null  float64
#  9   hazardous           90836 non-null  bool
# dtypes: bool(2), float64(5), int64(1), object(2)
# memory usage: 5.7+ MB

# %%
df.shape
# Out:
# (90836, 10)

# %%
df.dtypes
# Out:
# id                      int64
# name                   object
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %% [markdown]
# # **Data Cleaning**
#
# 1. Misssing Values: This dataset is report (or) is a record of all the asteroids, meteors, detached rocket particles drifting in space and revolving around earth’s orbit. There are no null, missing, and NaN values in this dataset. Some null are present in ‘Estimated diameter max’ column but these values are used for classification
#
# 2. Clear Formatting: We used clear formatting in our code to make the columns more readable and simplified to use in the EDA process, this process is also used to implement another data cleaning method (splitting).
#
# 3. Outliners: Outliners in the data are a separate set of data points which stays with the rest of the values, within the dataset the outliners can fluctuate the output. Outliners can be detected when abnormal distribution of data points occur (or) we can use boxplot function to detect the outliners. Here in our data we are removing 75% of the outliners because the data distribution is disturbed and the output graphs are being fluctuated.
#
#  We used IQR method to split the outliners using quantile function
#
# 4. Splitting Columns: In our data-frame we are splitting columns into 2 and adding them to our dataset in order to perform further classification, categorical columns are being split into 2. By using this method we can understand the data properly.
#
# 5. Duplicate Entries: Our dataset does not have any duplicated values and if we had duplicate values they are important because our dataset is based on the micro details, even the decimals are important for the classification process because our dataset revolves around all the object that might hit the earth, so due to lack of visual observation of the tiny particles we rely on this data.
#
# 6. Inconsistent Data: Our dataset has many inconsistent data but these values are useful for further processing, for example in the column ‘Estimated diameter max’ there are similar values, NaN values all the values are replaced to 0 because the all the information missing in this column can be compensated from another column.
#
# 7. Data Transformation: This process is essential because our dataset contains over 90000 rows, all the EDA graphs should be plotted in a large scale all the graphs are skewed to the left and some are skewed to the right so we use log transformation to normalize the data and use this normalized data to plot graphs.

# %% [markdown]
# # **Missing Values**

# %%
df.nunique()
# Out:
# id                    27423
# name                  27423
# est_diameter_min       1638
# est_diameter_max       1638
# relative_velocity     90828
# miss_distance         90536
# orbiting_body             1
# sentry_object             1
# absolute_magnitude     1638
# hazardous                 2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# name                  0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# orbiting_body         0
# sentry_object         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
df.isnull().sum()/(len(df))*100
# Out:
# id                    0.0
# name                  0.0
# est_diameter_min      0.0
# est_diameter_max      0.0
# relative_velocity     0.0
# miss_distance         0.0
# orbiting_body         0.0
# sentry_object         0.0
# absolute_magnitude    0.0
# hazardous             0.0
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %% [markdown]
# # **Clear Formatting**

# %%
df.rename(columns={'id': 'ID'}, inplace=True)
df.head()
# Out:
#         ID                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
df.rename(columns={'name': 'Name'}, inplace=True)
df.head()
# Out:
#         ID                 Name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
df.rename(columns={'est_diameter_min': 'Estimated_diameter_MIN'}, inplace=True)
df.head()
# Out:
#         ID                 Name  Estimated_diameter_MIN  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)                1.198271          2.679415
# 1  2277475    277475 (2005 WK4)                0.265800          0.594347
# 2  2512244   512244 (2015 YE18)                0.722030          1.614507
# 3  3596030          (2012 BV13)                0.096506          0.215794
# 4  3667127          (2014 GE35)                0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
df.rename(columns={'est_diameter_max': 'Estimated_diameter_MAX'}, inplace=True)
df.head()
# Out:
#         ID                 Name  Estimated_diameter_MIN  \
# 0  2162635  162635 (2000 SS164)                1.198271
# 1  2277475    277475 (2005 WK4)                0.265800
# 2  2512244   512244 (2015 YE18)                0.722030
# 3  3596030          (2012 BV13)                0.096506
# 4  3667127          (2014 GE35)                0.255009
#
#    Estimated_diameter_MAX  relative_velocity  miss_distance orbiting_body  \
# 0                2.679415       13569.249224   5.483974e+07         Earth
# 1                0.594347       73588.726663   6.143813e+07         Earth
# 2                1.614507      114258.692129   4.979872e+07         Earth
# 3                0.215794       24764.303138   2.543497e+07         Earth
# 4                0.570217       42737.733765   4.627557e+07         Earth
#
#    sentry_object  absolute_magnitude  hazardous
# 0          False               16.73      False
# 1          False               20.00       True
# 2          False               17.83      False
# 3          False               22.20      False
# 4          False               20.09       True

# %%
df.rename(columns={'sentry_object': 'Monitored_by_Sentry'}, inplace=True)
df.head()
# Out:
#         ID                 Name  Estimated_diameter_MIN  \
# 0  2162635  162635 (2000 SS164)                1.198271
# 1  2277475    277475 (2005 WK4)                0.265800
# 2  2512244   512244 (2015 YE18)                0.722030
# 3  3596030          (2012 BV13)                0.096506
# 4  3667127          (2014 GE35)                0.255009
#
#    Estimated_diameter_MAX  relative_velocity  miss_distance orbiting_body  \
# 0                2.679415       13569.249224   5.483974e+07         Earth
# 1                0.594347       73588.726663   6.143813e+07         Earth
# 2                1.614507      114258.692129   4.979872e+07         Earth
# 3                0.215794       24764.303138   2.543497e+07         Earth
# 4                0.570217       42737.733765   4.627557e+07         Earth
#
#    Monitored_by_Sentry  absolute_magnitude  hazardous
# 0                False               16.73      False
# 1                False               20.00       True
# 2                False               17.83      False
# 3                False               22.20      False
# 4                False               20.09       True

# %%
cat_columns = df.select_dtypes(['object']).columns

df[cat_columns] = df[cat_columns].apply(lambda x: pd.factorize(x)[0])

# %%
df['hazardous']
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 90831    False
# 90832    False
# 90833    False
# 90834    False
# 90835    False
# Name: hazardous, Length: 90836, dtype: bool

# %%
df
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                False
# 1           73588.726663   6.143813e+07              0                False
# 2          114258.692129   4.979872e+07              0                False
# 3           24764.303138   2.543497e+07              0                False
# 4           42737.733765   4.627557e+07              0                False
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                False
# 90832       46114.605073   5.432121e+07              0                False
# 90833        7566.807732   2.840077e+07              0                False
# 90834       69199.154484   6.869206e+07              0                False
# 90835       27024.455553   5.977213e+07              0                False
#
#        absolute_magnitude  hazardous
# 0                   16.73      False
# 1                   20.00       True
# 2                   17.83      False
# 3                   22.20      False
# 4                   20.09       True
# ...                   ...        ...
# 90831               25.00      False
# 90832               26.00      False
# 90833               24.60      False
# 90834               27.80      False
# 90835               24.12      False
#
# [90836 rows x 10 columns]

# %%
cat_columns = df.select_dtypes(['bool']).columns

df[cat_columns] = df[cat_columns].apply(lambda x: pd.factorize(x)[0])

# %%
df
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                    0
# 1           73588.726663   6.143813e+07              0                    0
# 2          114258.692129   4.979872e+07              0                    0
# 3           24764.303138   2.543497e+07              0                    0
# 4           42737.733765   4.627557e+07              0                    0
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                    0
# 90832       46114.605073   5.432121e+07              0                    0
# 90833        7566.807732   2.840077e+07              0                    0
# 90834       69199.154484   6.869206e+07              0                    0
# 90835       27024.455553   5.977213e+07              0                    0
#
#        absolute_magnitude  hazardous
# 0                   16.73          0
# 1                   20.00          1
# 2                   17.83          0
# 3                   22.20          0
# 4                   20.09          1
# ...                   ...        ...
# 90831               25.00          0
# 90832               26.00          0
# 90833               24.60          0
# 90834               27.80          0
# 90835               24.12          0
#
# [90836 rows x 10 columns]

# %%
df.apply(pd.to_numeric)
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                    0
# 1           73588.726663   6.143813e+07              0                    0
# 2          114258.692129   4.979872e+07              0                    0
# 3           24764.303138   2.543497e+07              0                    0
# 4           42737.733765   4.627557e+07              0                    0
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                    0
# 90832       46114.605073   5.432121e+07              0                    0
# 90833        7566.807732   2.840077e+07              0                    0
# 90834       69199.154484   6.869206e+07              0                    0
# 90835       27024.455553   5.977213e+07              0                    0
#
#        absolute_magnitude  hazardous
# 0                   16.73          0
# 1                   20.00          1
# 2                   17.83          0
# 3                   22.20          0
# 4                   20.09          1
# ...                   ...        ...
# 90831               25.00          0
# 90832               26.00          0
# 90833               24.60          0
# 90834               27.80          0
# 90835               24.12          0
#
# [90836 rows x 10 columns]

# %%
df.rename(columns={'absolute_magnitude': 'Impact_Magnitude'}, inplace=True)
df.head()
# Out:
#         ID  Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0  2162635     0                1.198271                2.679415
# 1  2277475     1                0.265800                0.594347
# 2  2512244     2                0.722030                1.614507
# 3  3596030     3                0.096506                0.215794
# 4  3667127     4                0.255009                0.570217
#
#    relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0       13569.249224   5.483974e+07              0                    0
# 1       73588.726663   6.143813e+07              0                    0
# 2      114258.692129   4.979872e+07              0                    0
# 3       24764.303138   2.543497e+07              0                    0
# 4       42737.733765   4.627557e+07              0                    0
#
#    Impact_Magnitude  hazardous
# 0             16.73          0
# 1             20.00          1
# 2             17.83          0
# 3             22.20          0
# 4             20.09          1

# %% [markdown]
# # **Outliners**

# %%
print(df.columns.unique())
print(df.columns.nunique())
# Out:
# Index(['ID', 'Name', 'Estimated_diameter_MIN', 'Estimated_diameter_MAX',
#        'relative_velocity', 'miss_distance', 'orbiting_body',
#        'Monitored_by_Sentry', 'Impact_Magnitude', 'hazardous'],
#       dtype='object')
# 10

# %%
categorical_columns=df.select_dtypes(include=['object']).columns
Numerical_columns = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Values:")
print(categorical_columns)
print("Numerical Values:")
print(Numerical_columns)
# Out:
# Categorical Values:
# Index([], dtype='object')
# Numerical Values:
# ['ID', 'Name', 'Estimated_diameter_MIN', 'Estimated_diameter_MAX', 'relative_velocity', 'miss_distance', 'orbiting_body', 'Monitored_by_Sentry', 'Impact_Magnitude', 'hazardous']

# %%
df.boxplot(Numerical_columns)
# Out:
# <AxesSubplot:>

# %%
df.boxplot('Impact_Magnitude')
# Out:
# <AxesSubplot:>

# %%
split1 = df['Impact_Magnitude'].quantile(0.25)
split2 = df['Impact_Magnitude'].quantile(0.75)

# %%
IQR_func=split2-split2
Upper_bound = split2 + 1.5 * IQR_func
Lower_bound = split2 - 1.5 * IQR_func
df[df['Impact_Magnitude'] > Upper_bound]
df[df['Impact_Magnitude'] < Lower_bound]
new_df = df[df['Impact_Magnitude'] < Upper_bound]
new_df1 = df[df['Impact_Magnitude'] > Lower_bound]
new_df.shape
new_df1.shape
# Out:
# (22166, 10)

# %%
sns.boxplot(df['Impact_Magnitude'])
plt.show()
sns.boxplot(new_df['Impact_Magnitude'])
plt.show()

# %%
split1 = df['Estimated_diameter_MIN'].quantile(0.25)
split2 = df['Estimated_diameter_MIN'].quantile(0.75)

# %%
IQR_func=split2-split2
Upper_bound = split2 + 1.5 * IQR_func
Lower_bound = split2 - 1.5 * IQR_func
df[df['Estimated_diameter_MIN'] > Upper_bound]
df[df['Estimated_diameter_MIN'] < Lower_bound]
new_df = df[df['Estimated_diameter_MIN'] < Upper_bound]
new_df.shape
# Out:
# (68095, 10)

# %%
sns.boxplot(df['Estimated_diameter_MIN'])
plt.show()
sns.boxplot(new_df['Estimated_diameter_MIN'])
plt.show()

# %%
split1 = df['Estimated_diameter_MAX'].quantile(0.25)
split2 = df['Estimated_diameter_MAX'].quantile(0.75)

# %%
IQR_func=split2-split2
Upper_bound = split2 + 1.5 * IQR_func
Lower_bound = split2 - 1.5 * IQR_func
df[df['Estimated_diameter_MAX'] > Upper_bound]
df[df['Estimated_diameter_MAX'] < Lower_bound]
new_df = df[df['Estimated_diameter_MAX'] < Upper_bound]
new_df1 = df[df['Estimated_diameter_MAX'] > Lower_bound]
new_df.shape
new_df1.shape
# Out:
# (22686, 10)

# %%
sns.boxplot(df['Estimated_diameter_MAX'])
plt.show()
sns.boxplot(new_df['Estimated_diameter_MAX'])
plt.show()

# %%
df.boxplot('relative_velocity')
# Out:
# <AxesSubplot:>

# %%
split1 = df['relative_velocity'].quantile(0.25)
split2 = df['relative_velocity'].quantile(0.75)

# %%
IQR_func=split2-split2
Upper_bound = split2 + 1.5 * IQR_func
Lower_bound = split2 - 1.5 * IQR_func
df[df['relative_velocity'] > Upper_bound]
df[df['relative_velocity'] < Lower_bound]
new_df = df[df['relative_velocity'] < Upper_bound]
new_df.shape
# Out:
# (68127, 10)

# %%
sns.boxplot(df['relative_velocity'])
plt.show()
sns.boxplot(new_df['relative_velocity'])
plt.show()

# %%
df.boxplot('miss_distance')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **Duplicate Entries**

# %%
df_duplicated=df.drop_duplicates('Name')
df.duplicated('Name')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 90831     True
# 90832     True
# 90833     True
# 90834     True
# 90835     True
# Length: 90836, dtype: bool

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 90831    False
# 90832    False
# 90833    False
# 90834    False
# 90835    False
# Length: 90836, dtype: bool

# %% [markdown]
# # **Inconsistent Data**

# %%
df.describe()
# Out:
#                  ID          Name  Estimated_diameter_MIN  \
# count  9.083600e+04  90836.000000            90836.000000
# mean   1.438288e+07   9124.264730                0.127432
# std    2.087202e+07   7104.415027                0.298511
# min    2.000433e+06      0.000000                0.000609
# 25%    3.448110e+06   3176.000000                0.019256
# 50%    3.748362e+06   7393.000000                0.048368
# 75%    3.884023e+06  14127.250000                0.143402
# max    5.427591e+07  27422.000000               37.892650
#
#        Estimated_diameter_MAX  relative_velocity  miss_distance  \
# count            90836.000000       90836.000000   9.083600e+04
# mean                 0.284947       48066.918918   3.706655e+07
# std                  0.667491       25293.296961   2.235204e+07
# min                  0.001362         203.346433   6.745533e+03
# 25%                  0.043057       28619.020645   1.721082e+07
# 50%                  0.108153       44190.117890   3.784658e+07
# 75%                  0.320656       62923.604633   5.654900e+07
# max                 84.730541      236990.128088   7.479865e+07
#
#        orbiting_body  Monitored_by_Sentry  Impact_Magnitude     hazardous
# count        90836.0              90836.0      90836.000000  90836.000000
# mean             0.0                  0.0         23.527103      0.097318
# std              0.0                  0.0          2.894086      0.296392
# min              0.0                  0.0          9.230000      0.000000
# 25%              0.0                  0.0         21.340000      0.000000
# 50%              0.0                  0.0         23.700000      0.000000
# 75%              0.0                  0.0         25.700000      0.000000
# max              0.0                  0.0         33.200000      1.000000

# %%
df['ID'].value_counts(dropna=False)
# Out:
# 2469219    43
# 2277810    43
# 3743123    40
# 2138175    39
# 3893865    38
#            ..
# 3768019     1
# 3774692     1
# 3779049     1
# 3775040     1
# 3092229     1
# Name: ID, Length: 27423, dtype: int64

# %%
df['miss_distance'].value_counts(dropna=False)
# Out:
# 5.603158e+07    2
# 7.001952e+07    2
# 4.926247e+07    2
# 9.079336e+06    2
# 5.178607e+07    2
#                ..
# 4.460245e+07    1
# 3.311994e+07    1
# 2.283126e+07    1
# 3.238010e+07    1
# 5.977213e+07    1
# Name: miss_distance, Length: 90536, dtype: int64

# %%
df['relative_velocity'].value_counts(dropna=False)
# Out:
# 34485.841845     2
# 25338.439042     2
# 37225.231825     2
# 36419.712852     2
# 66082.373737     2
#                 ..
# 102750.018447    1
# 27858.417772     1
# 18156.451169     1
# 18470.701216     1
# 27024.455553     1
# Name: relative_velocity, Length: 90828, dtype: int64

# %%
df.drop_duplicates()
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                    0
# 1           73588.726663   6.143813e+07              0                    0
# 2          114258.692129   4.979872e+07              0                    0
# 3           24764.303138   2.543497e+07              0                    0
# 4           42737.733765   4.627557e+07              0                    0
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                    0
# 90832       46114.605073   5.432121e+07              0                    0
# 90833        7566.807732   2.840077e+07              0                    0
# 90834       69199.154484   6.869206e+07              0                    0
# 90835       27024.455553   5.977213e+07              0                    0
#
#        Impact_Magnitude  hazardous
# 0                 16.73          0
# 1                 20.00          1
# 2                 17.83          0
# 3                 22.20          0
# 4                 20.09          1
# ...                 ...        ...
# 90831             25.00          0
# 90832             26.00          0
# 90833             24.60          0
# 90834             27.80          0
# 90835             24.12          0
#
# [90836 rows x 10 columns]

# %%
df.fillna(0)
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                    0
# 1           73588.726663   6.143813e+07              0                    0
# 2          114258.692129   4.979872e+07              0                    0
# 3           24764.303138   2.543497e+07              0                    0
# 4           42737.733765   4.627557e+07              0                    0
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                    0
# 90832       46114.605073   5.432121e+07              0                    0
# 90833        7566.807732   2.840077e+07              0                    0
# 90834       69199.154484   6.869206e+07              0                    0
# 90835       27024.455553   5.977213e+07              0                    0
#
#        Impact_Magnitude  hazardous
# 0                 16.73          0
# 1                 20.00          1
# 2                 17.83          0
# 3                 22.20          0
# 4                 20.09          1
# ...                 ...        ...
# 90831             25.00          0
# 90832             26.00          0
# 90833             24.60          0
# 90834             27.80          0
# 90835             24.12          0
#
# [90836 rows x 10 columns]

# %%
df['miss_distance']=df['miss_distance'].astype(float).replace('\0',regex=True)

# %%
df.head()
# Out:
#         ID  Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0  2162635     0                1.198271                2.679415
# 1  2277475     1                0.265800                0.594347
# 2  2512244     2                0.722030                1.614507
# 3  3596030     3                0.096506                0.215794
# 4  3667127     4                0.255009                0.570217
#
#    relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0       13569.249224   5.483974e+07              0                    0
# 1       73588.726663   6.143813e+07              0                    0
# 2      114258.692129   4.979872e+07              0                    0
# 3       24764.303138   2.543497e+07              0                    0
# 4       42737.733765   4.627557e+07              0                    0
#
#    Impact_Magnitude  hazardous
# 0             16.73          0
# 1             20.00          1
# 2             17.83          0
# 3             22.20          0
# 4             20.09          1

# %% [markdown]
# # **DATA TRANSFORMATION**

# %%
def log_transform(df,column_t):
    for column_name in column_t:
        if (df[column_name] == 1.0).all():
            df[column_name + '_log'] = np.log(df[column_name]+1)
        else:
            df[column_name + '_log'] = np.log(df[column_name])
    df.info()
log_transform(df,['Estimated_diameter_MIN','Estimated_diameter_MAX'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          90836 non-null  int64
#  1   Name                        90836 non-null  int64
#  2   Estimated_diameter_MIN      90836 non-null  float64
#  3   Estimated_diameter_MAX      90836 non-null  float64
#  4   relative_velocity           90836 non-null  float64
#  5   miss_distance               90836 non-null  float64
#  6   orbiting_body               90836 non-null  int64
#  7   Monitored_by_Sentry         90836 non-null  int64
#  8   Impact_Magnitude            90836 non-null  float64
#  9   hazardous                   90836 non-null  int64
#  10  Estimated_diameter_MIN_log  90836 non-null  float64
#  11  Estimated_diameter_MAX_log  90836 non-null  float64
# dtypes: float64(7), int64(5)
# memory usage: 8.3 MB

# %%
def log_transform(df,column_t):
    for column_name in column_t:
        if (df[column_name] == 1.0).all():
            df[column_name + '_log'] = np.log(df[column_name]+1)
        else:
            df[column_name + '_log'] = np.log(df[column_name])
    df.info()
log_transform(df,['relative_velocity','miss_distance'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          90836 non-null  int64
#  1   Name                        90836 non-null  int64
#  2   Estimated_diameter_MIN      90836 non-null  float64
#  3   Estimated_diameter_MAX      90836 non-null  float64
#  4   relative_velocity           90836 non-null  float64
#  5   miss_distance               90836 non-null  float64
#  6   orbiting_body               90836 non-null  int64
#  7   Monitored_by_Sentry         90836 non-null  int64
#  8   Impact_Magnitude            90836 non-null  float64
#  9   hazardous                   90836 non-null  int64
#  10  Estimated_diameter_MIN_log  90836 non-null  float64
#  11  Estimated_diameter_MAX_log  90836 non-null  float64
#  12  relative_velocity_log       90836 non-null  float64
#  13  miss_distance_log           90836 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 9.7 MB

# %%
def log_transform(df,column_t):
    for column_name in column_t:
        if (df[column_name] == 1.0).all():
            df[column_name + '_log'] = np.log(df[column_name]+1)
        else:
            df[column_name + '_log'] = np.log(df[column_name])
    df.info()
log_transform(df,['Impact_Magnitude'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          90836 non-null  int64
#  1   Name                        90836 non-null  int64
#  2   Estimated_diameter_MIN      90836 non-null  float64
#  3   Estimated_diameter_MAX      90836 non-null  float64
#  4   relative_velocity           90836 non-null  float64
#  5   miss_distance               90836 non-null  float64
#  6   orbiting_body               90836 non-null  int64
#  7   Monitored_by_Sentry         90836 non-null  int64
#  8   Impact_Magnitude            90836 non-null  float64
#  9   hazardous                   90836 non-null  int64
#  10  Estimated_diameter_MIN_log  90836 non-null  float64
#  11  Estimated_diameter_MAX_log  90836 non-null  float64
#  12  relative_velocity_log       90836 non-null  float64
#  13  miss_distance_log           90836 non-null  float64
#  14  Impact_Magnitude_log        90836 non-null  float64
# dtypes: float64(10), int64(5)
# memory usage: 10.4 MB

# %%
df.head()
# Out:
#         ID  Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0  2162635     0                1.198271                2.679415
# 1  2277475     1                0.265800                0.594347
# 2  2512244     2                0.722030                1.614507
# 3  3596030     3                0.096506                0.215794
# 4  3667127     4                0.255009                0.570217
#
#    relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0       13569.249224   5.483974e+07              0                    0
# 1       73588.726663   6.143813e+07              0                    0
# 2      114258.692129   4.979872e+07              0                    0
# 3       24764.303138   2.543497e+07              0                    0
# 4       42737.733765   4.627557e+07              0                    0
#
#    Impact_Magnitude  hazardous  Estimated_diameter_MIN_log  \
# 0             16.73          0                    0.180880
# 1             20.00          1                   -1.325011
# 2             17.83          0                   -0.325689
# 3             22.20          0                   -2.338149
# 4             20.09          1                   -1.366458
#
#    Estimated_diameter_MAX_log  relative_velocity_log  miss_distance_log  \
# 0                    0.985598               9.515561          17.819926
# 1                   -0.520292              11.206247          17.933541
# 2                    0.479030              11.646220          17.723500
# 3                   -1.533430              10.117159          17.051636
# 4                   -0.561739              10.662838          17.650125
#
#    Impact_Magnitude_log
# 0              2.817204
# 1              2.995732
# 2              2.880882
# 3              3.100092
# 4              3.000222

# %%
sns.distplot(df['Estimated_diameter_MAX_log'])
# Out:
# <AxesSubplot:xlabel='Estimated_diameter_MAX_log', ylabel='Density'>

# %%
sns.distplot(df['Estimated_diameter_MIN_log'])
# Out:
# <AxesSubplot:xlabel='Estimated_diameter_MIN_log', ylabel='Density'>

# %%
sns.distplot(df['Impact_Magnitude_log'])
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Density'>

# %% [markdown]
# # **EDA(Explanatory Data Analysis) Univariate Analysis**

# %%
categorical_columns=df.select_dtypes(include=['object']).columns
Numerical_columns = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Values:")
print(categorical_columns)
print("Numerical Values:")
print(Numerical_columns)
# Out:
# Categorical Values:
# Index([], dtype='object')
# Numerical Values:
# ['ID', 'Name', 'Estimated_diameter_MIN', 'Estimated_diameter_MAX', 'relative_velocity', 'miss_distance', 'orbiting_body', 'Monitored_by_Sentry', 'Impact_Magnitude', 'hazardous', 'Estimated_diameter_MIN_log', 'Estimated_diameter_MAX_log', 'relative_velocity_log', 'miss_distance_log', 'Impact_Magnitude_log']

# %%
df.describe(include='all').T
# Out:
#                               count          mean           std           min  \
# ID                          90836.0  1.438288e+07  2.087202e+07  2.000433e+06
# Name                        90836.0  9.124265e+03  7.104415e+03  0.000000e+00
# Estimated_diameter_MIN      90836.0  1.274321e-01  2.985112e-01  6.089126e-04
# Estimated_diameter_MAX      90836.0  2.849469e-01  6.674914e-01  1.361570e-03
# relative_velocity           90836.0  4.806692e+04  2.529330e+04  2.033464e+02
# miss_distance               90836.0  3.706655e+07  2.235204e+07  6.745533e+03
# orbiting_body               90836.0  0.000000e+00  0.000000e+00  0.000000e+00
# Monitored_by_Sentry         90836.0  0.000000e+00  0.000000e+00  0.000000e+00
# Impact_Magnitude            90836.0  2.352710e+01  2.894086e+00  9.230000e+00
# hazardous                   90836.0  9.731824e-02  2.963923e-01  0.000000e+00
# Estimated_diameter_MIN_log  90836.0 -2.949302e+00  1.332776e+00 -7.403836e+00
# Estimated_diameter_MAX_log  90836.0 -2.144583e+00  1.332776e+00 -6.599117e+00
# relative_velocity_log       90836.0  1.063015e+01  5.811445e-01  5.314911e+00
# miss_distance_log           90836.0  1.705499e+01  1.137470e+00  8.816636e+00
# Impact_Magnitude_log        90836.0  3.150343e+00  1.261724e-01  2.222459e+00
#
#                                      25%           50%           75%  \
# ID                          3.448110e+06  3.748362e+06  3.884023e+06
# Name                        3.176000e+03  7.393000e+03  1.412725e+04
# Estimated_diameter_MIN      1.925551e-02  4.836765e-02  1.434019e-01
# Estimated_diameter_MAX      4.305662e-02  1.081534e-01  3.206564e-01
# relative_velocity           2.861902e+04  4.419012e+04  6.292360e+04
# miss_distance               1.721082e+07  3.784658e+07  5.654900e+07
# orbiting_body               0.000000e+00  0.000000e+00  0.000000e+00
# Monitored_by_Sentry         0.000000e+00  0.000000e+00  0.000000e+00
# Impact_Magnitude            2.134000e+01  2.370000e+01  2.570000e+01
# hazardous                   0.000000e+00  0.000000e+00  0.000000e+00
# Estimated_diameter_MIN_log -3.949958e+00 -3.028924e+00 -1.942104e+00
# Estimated_diameter_MAX_log -3.145239e+00 -2.224205e+00 -1.137385e+00
# relative_velocity_log       1.026183e+01  1.069626e+01  1.104968e+01
# miss_distance_log           1.666105e+01  1.744905e+01  1.785062e+01
# Impact_Magnitude_log        3.060583e+00  3.165475e+00  3.246491e+00
#
#                                      max
# ID                          5.427591e+07
# Name                        2.742200e+04
# Estimated_diameter_MIN      3.789265e+01
# Estimated_diameter_MAX      8.473054e+01
# relative_velocity           2.369901e+05
# miss_distance               7.479865e+07
# orbiting_body               0.000000e+00
# Monitored_by_Sentry         0.000000e+00
# Impact_Magnitude            3.320000e+01
# hazardous                   1.000000e+00
# Estimated_diameter_MIN_log  3.634757e+00
# Estimated_diameter_MAX_log  4.439476e+00
# relative_velocity_log       1.237577e+01
# miss_distance_log           1.813031e+01
# Impact_Magnitude_log        3.502550e+00

# %% [markdown]
# # **BOX PLOT**

# %%
for Columns1 in Numerical_columns:
    print(Columns1)
    print(round(df[Columns1].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[Columns1].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[Columns1])
    plt.show()
# Out:
# ID
# 1.38
# Name
# 0.72
# Estimated_diameter_MIN
# 41.14
# Estimated_diameter_MAX
# 41.14
# relative_velocity
# 0.91
# miss_distance
# -0.04
# orbiting_body
# 0
# Monitored_by_Sentry
# 0
# Impact_Magnitude
# -0.14
# hazardous
# 2.72
# Estimated_diameter_MIN_log
# 0.14
# Estimated_diameter_MAX_log
# 0.14
# relative_velocity_log
# -0.69
# miss_distance_log
# -1.9
# Impact_Magnitude_log
# -0.45

# %% [markdown]
# # **HISTOGRAM**

# %%
for Columns1 in Numerical_columns:
    print(Columns1)
    print(round(df[Columns1].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[Columns1].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.histplot(x=df[Columns1])
    plt.show()
# Out:
# ID
# 1.38
# Name
# 0.72
# Estimated_diameter_MIN
# 41.14
# Estimated_diameter_MAX
# 41.14
# relative_velocity
# 0.91
# miss_distance
# -0.04
# orbiting_body
# 0
# Monitored_by_Sentry
# 0
# Impact_Magnitude
# -0.14
# hazardous
# 2.72
# Estimated_diameter_MIN_log
# 0.14
# Estimated_diameter_MAX_log
# 0.14
# relative_velocity_log
# -0.69
# miss_distance_log
# -1.9
# Impact_Magnitude_log
# -0.45

# %% [markdown]
# # **DENSITY PLOT**

# %%
for Columns1 in Numerical_columns:
    print(Columns1)
    print(round(df[Columns1].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[Columns1].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.distplot(x=df[Columns1])
    plt.show()
# Out:
# ID
# 1.38
# Name
# 0.72
# Estimated_diameter_MIN
# 41.14
# Estimated_diameter_MAX
# 41.14
# relative_velocity
# 0.91
# miss_distance
# -0.04
# orbiting_body
# 0
# Monitored_by_Sentry
# 0
# Impact_Magnitude
# -0.14
# hazardous
# 2.72
# Estimated_diameter_MIN_log
# 0.14
# Estimated_diameter_MAX_log
# 0.14
# relative_velocity_log
# -0.69
# miss_distance_log
# -1.9
# Impact_Magnitude_log
# -0.45

# %% [markdown]
# # **EDA (Exploratory Data Analysis) BIVARIATE ANALYSIS**

# %%
df.head()
# Out:
#         ID  Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0  2162635     0                1.198271                2.679415
# 1  2277475     1                0.265800                0.594347
# 2  2512244     2                0.722030                1.614507
# 3  3596030     3                0.096506                0.215794
# 4  3667127     4                0.255009                0.570217
#
#    relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0       13569.249224   5.483974e+07              0                    0
# 1       73588.726663   6.143813e+07              0                    0
# 2      114258.692129   4.979872e+07              0                    0
# 3       24764.303138   2.543497e+07              0                    0
# 4       42737.733765   4.627557e+07              0                    0
#
#    Impact_Magnitude  hazardous  Estimated_diameter_MIN_log  \
# 0             16.73          0                    0.180880
# 1             20.00          1                   -1.325011
# 2             17.83          0                   -0.325689
# 3             22.20          0                   -2.338149
# 4             20.09          1                   -1.366458
#
#    Estimated_diameter_MAX_log  relative_velocity_log  miss_distance_log  \
# 0                    0.985598               9.515561          17.819926
# 1                   -0.520292              11.206247          17.933541
# 2                    0.479030              11.646220          17.723500
# 3                   -1.533430              10.117159          17.051636
# 4                   -0.561739              10.662838          17.650125
#
#    Impact_Magnitude_log
# 0              2.817204
# 1              2.995732
# 2              2.880882
# 3              3.100092
# 4              3.000222

# %% [markdown]
# # **POINT PLOT**

# %%
sns.pointplot(x='Impact_Magnitude_log',y='Monitored_by_Sentry',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Monitored_by_Sentry'>

# %%
sns.pointplot(x='Impact_Magnitude_log',y='Estimated_diameter_MIN_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MIN_log'>

# %%
sns.pointplot(x='Impact_Magnitude_log',y='Estimated_diameter_MAX_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MAX_log'>

# %%
sns.pointplot(x='Impact_Magnitude_log',y='miss_distance_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='miss_distance_log'>

# %%
sns.pointplot(x='Impact_Magnitude_log',y='relative_velocity_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='relative_velocity_log'>

# %% [markdown]
# # **REGRESSION PLOT**

# %%
sns.regplot(x='Impact_Magnitude_log',y='Estimated_diameter_MIN_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MIN_log'>

# %%
sns.regplot(x='Impact_Magnitude_log',y='Monitored_by_Sentry',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Monitored_by_Sentry'>

# %%
sns.regplot(x='relative_velocity',y='Monitored_by_Sentry',data=df)
# Out:
# <AxesSubplot:xlabel='relative_velocity', ylabel='Monitored_by_Sentry'>

# %%
sns.regplot(x='relative_velocity_log',y='miss_distance',data=df)
# Out:
# <AxesSubplot:xlabel='relative_velocity_log', ylabel='miss_distance'>

# %%
sns.regplot(x='Impact_Magnitude_log',y='Estimated_diameter_MAX_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MAX_log'>

# %%
sns.regplot(x='Impact_Magnitude_log',y='miss_distance_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='miss_distance_log'>

# %%
sns.regplot(x='miss_distance_log',y='Estimated_diameter_MAX_log',data=df)
# Out:
# <AxesSubplot:xlabel='miss_distance_log', ylabel='Estimated_diameter_MAX_log'>

# %% [markdown]
# # **EDA (Exploratory Data Analysis) MULTIVARIATE ANALYSIS**

# %% [markdown]
# # **Pairplot**

# %%
sns.pairplot(df.drop(['Monitored_by_Sentry'],axis=1).corr())
plt.show()

# %% [markdown]
# # **Heatmap**

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(df.drop(['Monitored_by_Sentry'],axis=1).corr(), annot = True)
plt.show()

# %% [markdown]
# # **Scatter plot**

# %%
sns.scatterplot(x='Impact_Magnitude_log',y='Estimated_diameter_MIN_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MIN_log'>

# %%
sns.scatterplot(x='Impact_Magnitude_log',y='Monitored_by_Sentry',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Monitored_by_Sentry'>

# %%
sns.scatterplot(x='relative_velocity',y='Monitored_by_Sentry',data=df)
# Out:
# <AxesSubplot:xlabel='relative_velocity', ylabel='Monitored_by_Sentry'>

# %%
sns.scatterplot(x='relative_velocity_log',y='miss_distance',data=df)
# Out:
# <AxesSubplot:xlabel='relative_velocity_log', ylabel='miss_distance'>

# %%
sns.scatterplot(x='Impact_Magnitude_log',y='Estimated_diameter_MAX_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='Estimated_diameter_MAX_log'>

# %%
sns.scatterplot(x='Impact_Magnitude_log',y='miss_distance_log',data=df)
# Out:
# <AxesSubplot:xlabel='Impact_Magnitude_log', ylabel='miss_distance_log'>

# %%
sns.scatterplot(x='miss_distance_log',y='Estimated_diameter_MAX_log',data=df)
# Out:
# <AxesSubplot:xlabel='miss_distance_log', ylabel='Estimated_diameter_MAX_log'>

# %% [markdown]
# # **LM plot**

# %%
sns.lmplot(x='miss_distance_log',y='Estimated_diameter_MIN_log',data=df)

# %%
sns.lmplot(x='Impact_Magnitude_log',y='Estimated_diameter_MIN_log',data=df)

# %%
sns.lmplot(x='Impact_Magnitude_log',y='Monitored_by_Sentry',data=df)

# %%
sns.lmplot(x='relative_velocity',y='Monitored_by_Sentry',data=df)

# %%
sns.lmplot(x='relative_velocity_log',y='miss_distance',data=df)

# %%
sns.lmplot(x='Impact_Magnitude_log',y='Estimated_diameter_MAX_log',data=df)

# %%
sns.lmplot(x='Impact_Magnitude_log',y='miss_distance_log',data=df)

# %%
sns.lmplot(x='miss_distance_log',y='Estimated_diameter_MAX_log',data=df)

# %%
sns.lmplot(x='miss_distance_log',y='Estimated_diameter_MIN_log',data=df)

# %% [markdown]
# # PHASE 2

# %% [markdown]
# # Model Training

# %%
#Assigning the 'hazardous' column from the existing dataframe df to 'y'
y = pd.DataFrame(df['hazardous'],columns = ['hazardous'])

# %%
y
# Out:
#        hazardous
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# ...          ...
# 90831          0
# 90832          0
# 90833          0
# 90834          0
# 90835          0
#
# [90836 rows x 1 columns]

# %%
x = df.drop(columns = ['hazardous'])

# %%
x
# Out:
#              ID   Name  Estimated_diameter_MIN  Estimated_diameter_MAX  \
# 0       2162635      0                1.198271                2.679415
# 1       2277475      1                0.265800                0.594347
# 2       2512244      2                0.722030                1.614507
# 3       3596030      3                0.096506                0.215794
# 4       3667127      4                0.255009                0.570217
# ...         ...    ...                     ...                     ...
# 90831   3763337    629                0.026580                0.059435
# 90832   3837603   7599                0.016771                0.037501
# 90833  54017201  19445                0.031956                0.071456
# 90834  54115824   7737                0.007321                0.016370
# 90835  54205447  21816                0.039862                0.089133
#
#        relative_velocity  miss_distance  orbiting_body  Monitored_by_Sentry  \
# 0           13569.249224   5.483974e+07              0                    0
# 1           73588.726663   6.143813e+07              0                    0
# 2          114258.692129   4.979872e+07              0                    0
# 3           24764.303138   2.543497e+07              0                    0
# 4           42737.733765   4.627557e+07              0                    0
# ...                  ...            ...            ...                  ...
# 90831       52078.886692   1.230039e+07              0                    0
# 90832       46114.605073   5.432121e+07              0                    0
# 90833        7566.807732   2.840077e+07              0                    0
# 90834       69199.154484   6.869206e+07              0                    0
# 90835       27024.455553   5.977213e+07              0                    0
#
#        Impact_Magnitude  Estimated_diameter_MIN_log  \
# 0                 16.73                    0.180880
# 1                 20.00                   -1.325011
# 2                 17.83                   -0.325689
# 3                 22.20                   -2.338149
# 4                 20.09                   -1.366458
# ...                 ...                         ...
# 90831             25.00                   -3.627596
# 90832             26.00                   -4.088113
# 90833             24.60                   -3.443389
# 90834             27.80                   -4.917044
# 90835             24.12                   -3.222341
#
#        Estimated_diameter_MAX_log  relative_velocity_log  miss_distance_log  \
# 0                        0.985598               9.515561          17.819926
# 1                       -0.520292              11.206247          17.933541
# 2                        0.479030              11.646220          17.723500
# 3                       -1.533430              10.117159          17.051636
# 4                       -0.561739              10.662838          17.650125
# ...                           ...                    ...                ...
# 90831                   -2.822877              10.860515          16.325141
# 90832                   -3.283394              10.738885          17.810425
# 90833                   -2.638670               8.931527          17.161927
# 90834                   -4.112325              11.144744          18.045144
# 90835                   -2.417622              10.204497          17.906050
#
#        Impact_Magnitude_log
# 0                  2.817204
# 1                  2.995732
# 2                  2.880882
# 3                  3.100092
# 4                  3.000222
# ...                     ...
# 90831              3.218876
# 90832              3.258097
# 90833              3.202746
# 90834              3.325036
# 90835              3.183041
#
# [90836 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.6)

# %% [markdown]
# # K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred  = knn.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#Confusion Matrix

from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test, y_pred)*100
print("Accuracy:",accuracy)
# Out:
# Accuracy: 88.8169241495725

# %%
# Compute precision, recall, and F1 score
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     49162
#            1       0.36      0.18      0.23      5340
#
#     accuracy                           0.89     54502
#    macro avg       0.64      0.57      0.59     54502
# weighted avg       0.86      0.89      0.87     54502

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

LR = LogisticRegression(random_state=0).fit(X_train, y_train)
L_Regression=LR.predict(X_test)

# %%
#Confusion Matrix

from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, L_Regression)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
accuracy=accuracy_score(y_test, L_Regression)*100
print("Accuracy:",accuracy)
# Out:
# Accuracy: 90.1930204396169

# %%
# evaluate model on test set
y_pred = LR.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     49162
#            1       0.46      0.01      0.01      5340
#
#     accuracy                           0.90     54502
#    macro avg       0.68      0.50      0.48     54502
# weighted avg       0.86      0.90      0.86     54502

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
clf = GaussianNB()
clf.fit(X_train, y_train)
Naive_bayes = clf.predict(X_test)

# %%
#Confusion Matrix

from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, Naive_bayes)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
accuracy=accuracy_score(y_test, Naive_bayes)*100
print("Accuracy:",accuracy)
# Out:
# Accuracy: 88.72151480679608

# %%
# X_test and y_test are your test data
y_pred = clf.predict(X_test)

#Compute accuracy,precision, recall, and F1 score
precision_recall_fscore_support = classification_report(y_test, y_pred)

# Print the report
print(precision_recall_fscore_support)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     49162
#            1       0.27      0.09      0.14      5340
#
#     accuracy                           0.89     54502
#    macro avg       0.59      0.53      0.54     54502
# weighted avg       0.85      0.89      0.86     54502

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix 
from sklearn.metrics import precision_score, recall_score, f1_score
trees = tree.DecisionTreeClassifier()
trees.fit(X_train, y_train)
Decision_Tree = trees.predict(X_test)

# %%
##PHASE -3 
### creating a pickle file
import pickle
filename = 'DecisionTree'
pickle.dump(trees,open(filename,'wb'))
## PHASE -3

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, Decision_Tree)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, Decision_Tree)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
#Compute accuracy,precision, recall, and F1 score
accuracy=accuracy_score(y_test, Decision_Tree)*100
precision = precision_score(y_test, Decision_Tree, average='weighted')*100
recall = recall_score(y_test, Decision_Tree, average='weighted')*100
f1 = f1_score(y_test, Decision_Tree, average='weighted')*100
print("Accuracy:",accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)
# Out:
# Accuracy: 92.95989138013285
# Precision: 92.95695509478648
# Recall: 92.95989138013285
# F1 score: 92.95842163645136

# %%
#plot the decision tree
plt.figure(figsize=(25, 10))
plot_tree(trees, filled=True)
plt.show()

# %% [markdown]
# # Neural networks

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

NN = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=3)

NN.fit(X_train, y_train)
NN1 = NN.predict(X_test)

# %%
#Confusion Matrix

from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, roc_auc_score, precision_score, recall_score, f1_score

confusion_matrix = metrics.confusion_matrix(y_test, NN1)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
# assume that X_test and y_test are the test data and labels for the neural network model
NN1 = NN.predict(X_test)
accuracy=accuracy_score(y_test, NN1)*100
precision = precision_score(y_test, NN1, average='weighted')*100
recall = recall_score(y_test, NN1, average='weighted')*100
f1 = f1_score(y_test, NN1, average='weighted')*100
print("Accuracy:",accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)
# Out:
# Accuracy: 90.20219441488386
# Precision: 81.36435877260504
# Recall: 90.20219441488386
# F1 score: 85.55564673993904

# %% [markdown]
# # References :
#
# https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB
#
#
# https://scikit-learn.org/stable/modules/neural_networks_supervised
#
#
# https://scikit-learn.org/stable/modules/tree
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier

# %% [markdown]
# # PHASE 3

# %% [markdown]
# # Web application

# %%
#generateListforFeatures(features) takes a dictionary of features and 
#creates a list with 14 elements where each element corresponds to a feature.
def generateListforFeatures(features):
    feature_List = [0] * 14
    feature_List[0] = float(features['obj_id'])
    if features['obj_name'] == '':
        feature_List[1]=0
    else:
        feature_List[1]=1
    feature_List[2] = float(features['estimation_diameter_min'])
    feature_List[3] = float(features['estimation_diameter_max'])
    feature_List[4] = float(features['relative_velocity'])
    feature_List[5] = float(features['miss_distance'])
    if features['orbiting_body'] == 'Earth':
        feature_List[6] = 1
    else:
        feature_List[6] = 0
    if features['sentry_object'] == 'FALSE':
        feature_List[7] = 0
    else:
        feature_List[7] = 1
    feature_List[8] = float(features['Impact_Magnitude'])
    feature_List[9] = float(features['Est_dia_MIN_log'])
    feature_List[10] = float(features['Est_dia_MAX_log'])
    feature_List[11] = float(features['relative_velocity_log'])
    feature_List[12] = float(features['missed_distance_log'])
    feature_List[13] = float(features['Impact_Magnitude_log'])
    return feature_List

# %%
#@anvil.server.callable can be accessed by clients connected to an Anvil app server.
@anvil.server.callable
def collide(features):
    print("The inputs given by the end user are : , %s!" % features)
    model_inputs = generateListforFeatures(features)
    #print([np.array(model_inputs)])
    
    ### loading pickle file model   
    finalized_model = pickle.load(open(filename,'rb'))
    output = finalized_model.predict([np.array(model_inputs)])
    return(output[0])
    
#anvil.server.wait_forever() is used to keep the Anvil server running indefinitely, 
#waiting for incoming requests to the predict function.
anvil.server.wait_forever()
# Out:
# The inputs given by the end user are : , {'missed_distance_log': '17.8', 'relative_velocity_log': '9.51', 'Impact_Magnitude': '19.5', 'relative_velocity': '81401.7407267596', 'obj_id': '3724221', 'Est_dia_MIN_log': '0.18', 'orbiting_body': 'Earth', 'obj_name': '(2015 ME131)', 'Est_dia_MAX_log': '0.98', 'estimation_diameter_min': '0.3346223745', 'Impact_Magnitude_log': '2.8', 'sentry_object': 'FALSE', 'estimation_diameter_max': '0.7482383761', 'miss_distance': '51417974.5741842'}!
# The inputs given by the end user are : , {'missed_distance_log': '17.8', 'relative_velocity_log': '9.51', 'Impact_Magnitude': '19.5', 'relative_velocity': '81401.7407267596', 'obj_id': '3724221', 'Est_dia_MIN_log': '0.18', 'orbiting_body': 'Earth', 'obj_name': '(2015 ME131)', 'Est_dia_MAX_log': '0.98', 'estimation_diameter_min': '0.3346223745', 'Impact_Magnitude_log': '2.8', 'sentry_object': 'FALSE', 'estimation_diameter_max': '0.7482383761', 'miss_distance': '51417974.5741842'}!
# The inputs given by the end user are : , {'missed_distance_log': '17.8', 'relative_velocity_log': '9.51', 'Impact_Magnitude': '19.5', 'relative_velocity': '81401.7407267596', 'obj_id': '3724221', 'Est_dia_MIN_log': '0.18', 'orbiting_body': 'Earth', 'obj_name': '(2015 ME131)', 'Est_dia_MAX_log': '0.98', 'estimation_diameter_min': '0.3346223745', 'Impact_Magnitude_log': '2.8', 'sentry_object': 'FALSE', 'estimation_diameter_max': '0.7482383761', 'miss_distance': '51417974.5741842'}!
